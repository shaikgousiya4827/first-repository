# %%
class JuniorEngineer(Employee):
  def __init__(self,assessmentScore,feedback):
    self.assessmentScore=assessmentScore
    self.feedback=feedback
  def show(self):
    print("Assessment Score is:",self.assessmentScore)
    print("Feedback is:",self.feedback)
class SoftwareEngineer(Employee):
  def __init__(self,projectName):
    self.projectName=projectName
  def show(self):
    print("Project Name is:",self.projectName)
class Triner(Employee):
  def __init__(self,skills,certifications):
    self.skills=skills
    self.certifications=certifications
  def show(self):
    print("Skills are:",self.skills)
    print("certifications are:",self.certifications)
juniorEngineer=JuniorEngineer(99,"good")
softwareEngineer=SoftwareEngineer("AI Tools")
triner=Triner("Python","AWS")
juniorEngineer.show()
softwareEngineer.show()
triner.show()
# Out:
# Assessment Score is: 99
# Feedback is: good
# Project Name is: AI Tools
# Skills are: Python
# certifications are: AWS

# %%
address=Address(20,"Islampet","ongole","AP","India")
python_course=Course("python",100,"60 days")
ml_course=Course("ML",101,"100 Days")
junior=Junior_Engineer(1000,"Gousiya",10000,address,95,"Excellent")

junior.registeredCourse(ml_course)
junior.registeredCourse(python_course)

softwareEngineer=Software_Engineer(10001,"Yamini",100000,address,"marketing")

trainer=Trainer(10002,"Hari",2000000,address,["Java","Python","DS","ML"],["AWS","AZURE","Github Copilot"])

print("\n Junior Engineer Details are             ")
junior.print_details()
print("\n Software Engineer Details are           ")
softwareEngineer.print_details()
print("\n Trainer Details             ")
trainer.print_details()
# Out:
#  Junior Engineer Details are
#
# Employee Details are
# ----------------------------------------
# Employee Id is: 1000
# Employye Name is: Gousiya
# Employee Salary is: 10000
# Employee Address is: 20,Islampet,ongole,AP,India
#
# Employee Registered Courses are:
# ML 101 (100 Days)
# python 100 (60 days)
# Assessment Score is: 95
# Feedback is: Excellent
#
#  Software Engineer Details are
#
# Employee Details are
# ----------------------------------------
# Employee Id is: 10001
# Employye Name is: Yamini
# Employee Salary is: 100000
# Employee Address is: 20,Islampet,ongole,AP,India
#
# Employee Registered Courses are:
# Project Name is: marketing
#
#  Trainer Details
#
# Employee Details are
# ----------------------------------------
# Employee Id is: 10002
# Employye Name is: Hari
# Employee Salary is: 2000000
# Employee Address is: 20,Islampet,ongole,AP,India
#
# Employee Registered Courses are:
# Skills are: ['Java', 'Python', 'DS', 'ML']
# ...

# %%
#Day Calculation
class Daycalculation(Employee):
  def __init__(self,currentDay,k):
    self.currentDay=currentDay
    self.k=k
  def show(self):
    l=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
    for i in l:
      if i==self.currentDay:
        a=l.index(i)
        #p=(a+self.k)%7
        p=0
        while self.k>0:
          a+=1
          if a==7:
            a=0
          self.k-=1

    self.currentDay=l[a]
    print(self.currentDay)
daycalculation=Daycalculation("Tuesday",101)
daycalculation.show()
# Out:
# Friday

# %%
#Duplicate Characters
string = "ABC Company pvt lmt"

visited = []

for i in string:
    if i != " " and i not in visited:
      if string.count(i) > 1:
        print(i, "->", string.count(i))
      visited.append(i)
# Out:
# C -> 2
# m -> 2
# p -> 2
# t -> 2
